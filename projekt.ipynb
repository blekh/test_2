# %% [markdown]
# <a href="https://colab.research.google.com/github/blekh/test_2/blob/main/projekt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#jmeno a heslo od uzivatele 

username = input('Zadej své uživatelské jméno: ')
heslo = input('Zadej své heslo: ')
#seznam uzivatelu
uzivatele = [("bob","123"),("ann","pass123"),("mike","password123"), ("liz", "pass123")]
#kontola uzivatele 
if username == uzivatele[0][0] and heslo == uzivatele[0][1]:
    print("ahoj,",username.capitalize() +"e") 
elif username == uzivatele[1][0] and heslo == uzivatele[1][1]:
    print("ahoj,", username.capitalize() + "o")
elif username == uzivatele[2][0] and heslo == uzivatele[2][1]:
    print("ahoj,", username.capitalize() + "u")
elif username == uzivatele[3][0] and heslo == uzivatele[3][1]:
    print("ahoj,", username.capitalize() + "o")
else:
    print("Špatné uživatelské jméno nebo heslo, zkus to znovu!")
    exit()
#text
TEXTS = ['''
Situated about 10 miles west of Kemmerer, 
Fossil Butte is a ruggedly impressive 
topographic feature that rises sharply 
some 1000 feet above Twin Creek Valley 
to an elevation of more than 7500 feet 
above sea level. The butte is located just 
north of US 30N and the Union Pacific Railroad, 
which traverse the valley. ''',

'''At the base of Fossil Butte are the bright 
red, purple, yellow and gray beds of the Wasatch 
Formation. Eroded portions of these horizontal 
beds slope gradually upward from the valley floor 
and steepen abruptly. Overlying them and extending 
to the top of the butte are the much steeper 
buff-to-white beds of the Green River Formation, 
which are about 300 feet thick.''',

'''The monument contains 8198 acres and protects 
a portion of the largest deposit of freshwater fish 
fossils in the world. The richest fossil fish deposits 
are found in multiple limestone layers, which lie some 
100 feet below the top of the butte. The fossils 
represent several varieties of perch, as well as 
other freshwater genera and herring similar to those 
in modern oceans. Other fish such as paddlefish, 
garpike and stingray are also present.''']
#pořadi textu
TEXT = [("1",TEXTS[0]), ("2", TEXTS[1]), ("3", TEXTS[2])]
#vyber textu 
cislo_textu = input("vyber si čislo od 1 do 3: ")

#přrirazeni vybraneho cisla k textu
if cislo_textu == TEXT[0][0]:
    print("Vybral sis text:\n", TEXTS[0])
elif  cislo_textu == TEXT[1][0]:
    print("Vybral sis text:\n", TEXTS[1])
elif cislo_textu == TEXT[2][0]:
    print("Vybral sis text:\n", TEXTS[2])
elif cislo_textu.isalpha():
    print("zadal si text, musíš zadat čislo")
else:
    print("Čislo neni v textu, vyber si jiné číslo")

#celkovy pocet slov
pocet_slov = str(TEXTS[int(cislo_textu)-1]).split()
print("počet slov ve vybraném textu: ", len(pocet_slov))

#pocet slov zacinajicich velkým pismenem 
print("Počet slov psaných velkým pismenem:", sum(1 for word in pocet_slov if word.istitle()))

#pocet slov zacinajicich malym pismenem 
print("Počet slov psaných malým pismenem:", sum(1 for word in pocet_slov if word.islower()))

#pocet slov psanych pouze velkými pismeny
print("Počet slov psaných velkými pismeny:", sum(1 for word in pocet_slov if word.isupper() and word.isalpha()))

#pocet čisel v textu3
print("Počet cifer:", sum(1 for word in pocet_slov if word.isdigit()))


# vyskyt slov v textu 
vyskyt_slov = {}
for word in pocet_slov:
    vyskyt_slov[word] = vyskyt_slov.get(word, 0) + 1
    

nejcastejsi = sorted( vyskyt_slov, key=vyskyt_slov.get, reverse=True)[:9]
print(nejcastejsi)

oddelovac = "-" * 40
print(oddelovac)
print("LEN\t", "|", "OCCURANCY\t", "|", "\tNR")
print(oddelovac)
for poradi, klic in enumerate(nejcastejsi):
  print(len(klic), "\t", "|\t", vyskyt_slov[klic]*"*" ,"\t" "|\t", vyskyt_slov[klic])
print(oddelovac)
